# %%
#!/usr/bin/env python
from __future__ import print_function

import argparse
import skimage as skimage
from skimage import transform, color, exposure
from skimage.transform import rotate
from skimage.viewer import ImageViewer

import sys
import os
work_space = os.path.dirname(os.getcwd())
sys.path.append(work_space+"/game/")
import wrapped_flappy_bird as game
import random
import numpy as np
from collections import deque
import json
import os

from bigdl.optim.optimizer import *
from bigdl.nn.criterion import *
from zoo.pipeline.api.keras.models import Sequential
from zoo.pipeline.api.keras.layers import Dense, Dropout, Activation,Flatten,Convolution2D
import tensorflow as tf
# Out:
# /usr/local/lib/python2.7/dist-packages/skimage/viewer/utils/core.py:10: UserWarning: Recommended matplotlib backend is `Agg` for full skimage.viewer functionality.
#   warn("Recommended matplotlib backend is `Agg` for full "

# %%
def to_RDD(X, y):
    return sc.parallelize(X).zip(sc.parallelize(y)).map(
            lambda x: Sample.from_ndarray(x[0],x[1]))

# %%
def normalize(advantages, smallEps=1e-8):
    return (advantages - advantages.mean())/(advantages.std() + smallEps)

# %%
ACTION_PER_FRAME = 1
IMAGE_ROWS, IMAGE_COLS = 80, 80
IMAGE_CHANNELS = 4
ACTION_SIZE = 2
LEARNING_RATE = 1e-4
INITIAL_EPSILON = 0.1
FINAL_EPSILON = 0.0001
EXPLORE = 3000000
BATCH_SIZE = 2 # every how many eposides do a parameter update
GAMMA = 0.99
r_reward_moving_average = 0
average_step_record = list()

# %%
# the abstraction of birdagent
class BirdAgent:
    def __init__(self, state_size, action_size, gamma=0.95):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = deque(maxlen=2000)
        self.gamma = gamma
        self.model = self._build_mode()

    def _build_mode(self):
        print("Now we build the model")
        model = Sequential()
        model.add(Convolution2D(32, 8, 8, subsample=(4, 4), border_mode='same',
                                input_shape=(IMAGE_ROWS, IMAGE_COLS, IMAGE_CHANNELS)))  # 80*80*4
        model.add(Activation('relu'))
        model.add(Convolution2D(64, 4, 4, subsample=(2, 2), border_mode='same'))
        model.add(Activation('relu'))
        model.add(Convolution2D(64, 3, 3, subsample=(1, 1), border_mode='same'))
        model.add(Activation('relu'))
        model.add(Flatten())
        model.add(Dense(512))
        model.add(Activation('relu'))
        model.add(Dense(2))
        # get the 1 * 2 output represent each action's probability
        model.add(Activation('softmax'))
        return model

    # sample the action from the predict of the model
    def action_sampler(self, out):
        # return 1 if result > np.random.random() else 0
        return np.random.choice([0, 1], p=out)

    def act(self, state, epsilon = 0.01):
        explore = False
        random_num = random.random()
        action = np.zeros(2)
        if random_num <= epsilon:
            explore = True
            # ramdomly select an action
            action_index = random.randrange(ACTION_SIZE)
            action[action_index] = 1
            print("*********** Random Action *********** : ", action_index)
            return action,action,explore

        else:
            if isinstance(state, np.ndarray):
                features = to_sample_rdd(state, np.zeros([state.shape[0]]))
            out = self.model.predict(features)
            #print("out type",out)
            out = out.collect()
            
            if self.action_sampler(np.squeeze(out)) == 0:
                action[0] = 1
            else:
                action[1] = 1
            return np.squeeze(out),action,explore

# %%
def to_sample_rdd(x, y, numSlices=None):
    """
    Conver x and y into RDD[Sample]
    :param x: ndarray and the first dimension should be batch
    :param y: ndarray and the first dimension should be batch
    :param numSlices:
    :return:
    """
    sc = get_spark_context()
    from bigdl.util.common import Sample
    x_rdd = sc.parallelize(x, numSlices)
    y_rdd = sc.parallelize(y, numSlices)
    return x_rdd.zip(y_rdd).map(lambda item: Sample.from_ndarray(item[0], item[1]))

# %%
# the abstraction of rollouts
class RollOuts():
    def __init__(self, next_states, actions, rewards, logprobs, gradients, total_steps):
        self.next_states = next_states
        self.actions = actions
        self.rewards = rewards
        self.steps = total_steps
        self.logprobs = logprobs
        self.gradients = gradients
        self.total_rewards = np.sum(rewards)


    def get_summary(self):
        return {" total_reward ": self.total_rewards,
                " total_steps ": self.steps}


    def prepare_target(self):
        result = []
        for action, adv in list(zip(self.actions, self.advs)):
            adv = adv * action
            print('action and advantages : ',action, adv)
            result.append(adv)
        return np.array(result)

# %%
# the abstraction of experience memory
class ExperienceStroe:
    def __init__(self):
        self.rollouts = []

    def add_rollout(self, next_states, actions, rewards,logprobs, gradients, total_steps):
        self.rollouts.append(RollOuts(next_states, actions, rewards, logprobs, gradients,total_steps))

    def num_experiences(self):
        return len(self.rollouts)

    def get_range(self, start, end):
        return self.rollouts[start:end]

    def reset(self):
        self.rollouts = []

# %%
def stats_summary(rollouts, records, verbose=True):
    rollout_rewards = np.array([rollout.total_rewards for rollout in rollouts])
    print("reward mean %s" % (rollout_rewards.mean()))
    print("reward std %s" % (rollout_rewards.std()))
    print("reward max %s" % (rollout_rewards.max()))
    records.append([rollout_rewards.mean(), rollout_rewards.std()])

# %%
# calculate running reward
def cal_reward(rollouts, gamma, discounted=False):
    for rollout in rollouts:
        rewards = rollout.rewards
        r_reward = []
        running_reward = 0
        for reward in rewards[::-1]:
            # discounted reward
            # reward = (-1) * reward
            if discounted == True:
                running_reward = gamma * running_reward + reward
            else:
                running_reward = running_reward + reward
            r_reward.append(running_reward)
        rollout.r_rewards = np.squeeze(np.array(np.vstack(r_reward[::-1])))

# %%
def cal_advantage_moving_average(rollouts):
    r_reward_moving_average = 0
    for rollout in rollouts:
        advs = np.zeros([rollout.rewards.shape[0]])
        i = 0
        for r_reward in rollout.r_rewards:
            # calculate moving average
            r_reward_moving_average = (1-0.9) * r_reward_moving_average + 0.1 * r_reward
            # correct the bias
            advs[i] = r_reward - r_reward_moving_average
            i += 1
            rollout.advs = normalize(advs)

# %%
# calculate the advantage = reward - expected reward at this time step
def cal_advantage(rollouts):
    max_steps = max(rollout.rewards.shape[0] for rollout in rollouts)
    for rollout in rollouts:
        rollout.r_rewards = np.pad(rollout.r_rewards, (0, max_steps - rollout.r_rewards.shape[0]),'constant')
    baselines = np.mean(np.vstack([rollout.r_rewards for rollout in rollouts]), axis=0)
    for rollout in rollouts:
        rollout.advs = rollout.r_rewards - baselines
        rollout.advs = rollout.advs[:len(rollout.r_rewards)]
        rollout.r_rewards = rollout.r_rewards[:len(rollout.rewards)]

# %%
def play_game(agent, render=False):
    # 1. initialize
    # open up a game state to communicate with emulator
    game_state = game.GameState()
    # used to save the actions, should be a 1*2 nparray and sum(action) should be 1
    actions = np.zeros([1,2])
    # used to save the rewards
    rewards = np.array([])
    # get the first state by doing nothing and preprocess the image to 80x80x4
  
    gradients = np.zeros([1, 2])
    # should be (1*2) nparray and each col represent the probability to chose that action
    logprobs = np.array([1, 2])

    do_nothing = np.zeros(ACTION_SIZE)
    do_nothing[0] = 1
    x_t, r_0, terminal = game_state.frame_step(do_nothing)

    # preprocess the first frame
    x_t = skimage.color.rgb2gray(x_t)
    x_t = skimage.transform.resize(x_t, (80, 80))
    x_t = skimage.exposure.rescale_intensity(x_t, out_range=(0, 255))

    # rescale to 0-1
    x_t = x_t / 255.0

    # 80 * 80 * 4
    state = np.stack((x_t, x_t, x_t, x_t), axis=2)
    print (state.shape)
    # In Keras, need to reshape 1 * 80 * 80 * 4
    state = state.reshape(1, state.shape[0], state.shape[1], state.shape[2])  # 1*80*80*4
    # the observations will be batch_size * 80 * 80 * 4
    observations = np.zeros([1, state.shape[1], state.shape[2], state.shape[3]])
    for step in range(1, 500):
        # next state's shape, should be (1*80*80*4)
        
        # get the state list
        observations = np.vstack((observations, state))
        # predict the action

        logprob,action,explore = agent.act(state)
        
        
        actions = np.vstack((actions, action))
        logprobs = np.vstack((logprobs ,logprob))
        gradients = np.vstack((gradients , action.astype('float32') - logprob))
        # use the predicted action to determine the next state
        x_t1_colored, reward, terminal = game_state.frame_step(action)
        # print ('reward ',reward)
        # rgb to gray and rescale
        x_t1 = skimage.color.rgb2gray(x_t1_colored)
        x_t1 = skimage.transform.resize(x_t1, (80, 80))
        x_t1 = skimage.exposure.rescale_intensity(x_t1, out_range=(0, 255))
        # rescale to 0-1
        x_t1 = x_t1 / 255
        # update state
        x_t1 = x_t1.reshape(1,x_t1.shape[0],x_t1.shape[1],1)
        state = np.append(x_t1,state[:,:,:,:3],axis=3)
        rewards = np.append(rewards, reward)

        print('living steps : ',observations.shape[0])
        # print('state size ',state.shape)
        # print('action size : ',action.shape)
        # print('action : ',action)
        # print('reward : ',reward)
        # print('terminal : ',terminal)
        if terminal or step == 498:
            break
    return observations[1:], actions[1:], rewards , logprobs[1:], gradients[1:], step

# %%
def play_n_games(agent, history, n=4, verbose=True):
    start_eps = history.num_experiences()
    total_step = 0
    for i in range(n):
        observations, actions, rewards, logprobs, gradients, step = play_game(agent=agent)
        history.add_rollout(observations, actions, rewards, logprobs, gradients, step)
        total_step += step
    end_eps = history.num_experiences()
    return start_eps, end_eps, total_step

# %%
def learn(agent, rollouts):
    cal_reward(rollouts, agent.gamma)
    cal_advantage_moving_average(rollouts)
    #cal_advantage(rollouts)
    X_batch = np.zeros([1, 80, 80, 4])
    Y_batch = np.array([0,0])
    for rollout in rollouts:
        X_batch = np.vstack((X_batch, rollout.next_states))
        # Y_batch: the label of the training should be [[action,adv]]
        Y_batch = np.vstack((Y_batch, rollout.prepare_target()))
    X_batch = X_batch[1:]
    Y_batch = Y_batch[1:]
    Y_batch[:,1] = normalize(Y_batch[:,1])

    # Y_batch[:, 1] = normalize(y_batch[:, 1])
    # prepare to train the model
    print('X_batch size : ',X_batch.shape)
    print('Y_batch size : ',Y_batch.shape)
    rdd_sample = to_RDD(X_batch, Y_batch)
    batch_size = X_batch.shape[0] - X_batch.shape[0]%8
    print ("using batch_size = ",batch_size)
    
    optimizer = Optimizer(model=agent.model,
                                  training_rdd=rdd_sample,
                                  criterion=PGCriterion(),
                                  optim_method= RMSprop(learningrate=0.005),
                                  end_trigger=MaxIteration(1),
                                  batch_size=batch_size)
    #else:
        #optimizer.set_traindata(training_rdd=rdd_sample, batch_size=batch_size)
        #optimizer.set_criterion(RFPGCriterion())
    agent.model = optimizer.optimize()

# %%
import timeit
state_size = (1, 80, 80, 4)
action_size = ACTION_SIZE
agent = BirdAgent(state_size, action_size)
history = ExperienceStroe()
record = []
exe_times = []
history.reset()
train_start = 0
played_steps = 0
start_of_play = timeit.default_timer()
for i in range(1000):
    # history is a list of rollouts
    start_eps, end_eps, steps = play_n_games(agent, history, n=BATCH_SIZE)
    played_steps += steps
    train_end = end_eps
    end_of_play = timeit.default_timer()
    print
    "*************************"
    rollouts = history.get_range(start_eps, end_eps)
    stats_summary(rollouts, record)
    if (played_steps > BATCH_SIZE * 34):
        print("used in training: ", start_eps, "-", end_eps)
        print("num of total steps in training ", played_steps)
        start_of_train = timeit.default_timer()
        rollouts = history.get_range(train_start, train_end)
        print("training begin")
        learn(agent, rollouts)
        end_of_train = timeit.default_timer()
        exe_time_game_play = end_of_play - start_of_play
        train_time_game_paly = end_of_train - start_of_train
        exe_times.append([exe_time_game_play, train_time_game_paly])
        train_start = end_eps
        train_end = end_eps
        played_steps = 0
        start_of_play = timeit.default_timer()
# Out:
# Now we build the model
# creating: createZooKerasSequential
# creating: createZooKerasConvolution2D
# creating: createZooKerasActivation
# creating: createZooKerasConvolution2D
# creating: createZooKerasActivation
# creating: createZooKerasConvolution2D
# creating: createZooKerasActivation
# creating: createZooKerasFlatten
# creating: createZooKerasDense
# creating: createZooKerasActivation
# creating: createZooKerasDense
# creating: createZooKerasActivation
# (80, 80, 4)
# /usr/local/lib/python2.7/dist-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# living steps :  2
# living steps :  3
# living steps :  4
# living steps :  5
# living steps :  6
# living steps :  7
# living steps :  8
# living steps :  9
# living steps :  10
# living steps :  11
# living steps :  12
# living steps :  13
# living steps :  14
# living steps :  15
# living steps :  16
# *********** Random Action *********** :  1
# living steps :  17
# living steps :  18
# living steps :  19
# living steps :  20
# living steps :  21
# living steps :  22
# living steps :  23
# living steps :  24
# living steps :  25
# living steps :  26
# living steps :  27
# living steps :  28
# living steps :  29
# living steps :  30
# living steps :  31
# living steps :  32
# living steps :  33
# living steps :  34
# living steps :  35
# living steps :  36
# living steps :  37
# living steps :  38
# living steps :  39
# living steps :  40
# living steps :  41
# living steps :  42
# living steps :  43
# living steps :  44
# living steps :  45
# living steps :  46
# living steps :  47
# living steps :  48
# living steps :  49
# living steps :  50
# (80, 80, 4)
# living steps :  2
# living steps :  3
# living steps :  4
# living steps :  5
# living steps :  6
# living steps :  7
# living steps :  8
# living steps :  9
# living steps :  10
# living steps :  11
# living steps :  12
# living steps :  13
# living steps :  14
# living steps :  15
# living steps :  16
# living steps :  17
# living steps :  18
# living steps :  19
# living steps :  20
# living steps :  21
# living steps :  22
# living steps :  23
# living steps :  24
# living steps :  25
# living steps :  26
# living steps :  27
# living steps :  28
# living steps :  29
# living steps :  30
# living steps :  31
# living steps :  32
# living steps :  33
# living steps :  34
# living steps :  35
# living steps :  36
# living steps :  37
# living steps :  38
# living steps :  39
# living steps :  40
# living steps :  41
# living steps :  42
# living steps :  43
# living steps :  44
# living steps :  45
# living steps :  46
# living steps :  47
# living steps :  48
# living steps :  49
# living steps :  50
# reward mean 3.8
# reward std 0.0
# reward max 3.8
# used in training:  0 - 2
# num of total steps in training  98
# training begin
# action and advantages :  [1. 0.] [1.72853397 0.        ]
# action and advantages :  [0. 1.] [0.         1.62684638]
# action and advantages :  [1. 0.] [1.55312287 0.        ]
# action and advantages :  [0. 1.] [0.         1.48219577]
# action and advantages :  [0. 1.] [0.         1.41154832]
# action and advantages :  [1. 0.] [1.34092882 0.        ]
# action and advantages :  [0. 1.] [0.         1.27031213]
# action and advantages :  [0. 1.] [0.         1.19969571]
# action and advantages :  [1. 0.] [1.12907932 0.        ]
# action and advantages :  [1. 0.] [1.05846294 0.        ]
# action and advantages :  [1. 0.] [0.98784655 0.        ]
# action and advantages :  [0. 1.] [0.         0.91723017]
# action and advantages :  [1. 0.] [0.84661378 0.        ]
# action and advantages :  [0. 1.] [0.         0.77599739]
# action and advantages :  [0. 1.] [0.         0.70538101]
# action and advantages :  [0. 1.] [0.         0.63476462]
# action and advantages :  [0. 1.] [0.         0.56414824]
# action and advantages :  [1. 0.] [0.49353185 0.        ]
# action and advantages :  [1. 0.] [0.42291547 0.        ]
# action and advantages :  [1. 0.] [0.35229908 0.        ]
# action and advantages :  [1. 0.] [0.2816827 0.       ]
# action and advantages :  [0. 1.] [0.         0.21106631]
# action and advantages :  [0. 1.] [0.         0.14044992]
# action and advantages :  [1. 0.] [0.06983354 0.        ]
# action and advantages :  [0. 1.] [-0.         -0.00078285]
# action and advantages :  [1. 0.] [-0.07139923 -0.        ]
# action and advantages :  [0. 1.] [-0.         -0.14201562]
# action and advantages :  [0. 1.] [-0.       -0.212632]
# action and advantages :  [1. 0.] [-0.28324839 -0.        ]
# action and advantages :  [1. 0.] [-0.35386478 -0.        ]
# action and advantages :  [1. 0.] [-0.42448116 -0.        ]
# action and advantages :  [0. 1.] [-0.         -0.49509755]
# action and advantages :  [1. 0.] [-0.56571393 -0.        ]
# action and advantages :  [0. 1.] [-0.         -0.63633032]
# action and advantages :  [1. 0.] [-0.7069467 -0.       ]
# action and advantages :  [0. 1.] [-0.         -0.77756309]
# action and advantages :  [0. 1.] [-0.         -0.84817947]
# action and advantages :  [0. 1.] [-0.         -0.91879586]
# action and advantages :  [1. 0.] [-0.98941225 -0.        ]
# action and advantages :  [0. 1.] [-0.         -1.06002863]
# action and advantages :  [1. 0.] [-1.13064502 -0.        ]
# action and advantages :  [0. 1.] [-0.        -1.2012614]
# action and advantages :  [1. 0.] [-1.27187779 -0.        ]
# action and advantages :  [1. 0.] [-1.34249417 -0.        ]
# action and advantages :  [1. 0.] [-1.41311056 -0.        ]
# action and advantages :  [0. 1.] [-0.         -1.48372695]
# action and advantages :  [0. 1.] [-0.         -1.55434333]
# action and advantages :  [1. 0.] [-1.62495972 -0.        ]
# action and advantages :  [1. 0.] [-1.6955761 -0.       ]
# action and advantages :  [0. 1.] [0.         1.73647344]
# action and advantages :  [1. 0.] [1.62696708 0.        ]
# action and advantages :  [1. 0.] [1.55248334 0.        ]
# action and advantages :  [0. 1.] [0.         1.48150186]
# action and advantages :  [1. 0.] [1.41087061 0.        ]
# action and advantages :  [0. 1.] [0.         1.34027438]
# action and advantages :  [1. 0.] [1.26968166 0.        ]
# action and advantages :  [1. 0.] [1.19908928 0.        ]
# action and advantages :  [1. 0.] [1.12849694 0.        ]
# action and advantages :  [1. 0.] [1.0579046 0.       ]
# action and advantages :  [0. 1.] [0.         0.98731227]
# action and advantages :  [1. 0.] [0.91671993 0.        ]
# action and advantages :  [0. 1.] [0.         0.84612759]
# action and advantages :  [0. 1.] [0.         0.77553526]
# action and advantages :  [1. 0.] [0.70494292 0.        ]
# action and advantages :  [1. 0.] [0.63435058 0.        ]
# action and advantages :  [1. 0.] [0.56375824 0.        ]
# action and advantages :  [0. 1.] [0.         0.49316591]
# action and advantages :  [0. 1.] [0.         0.42257357]
# action and advantages :  [1. 0.] [0.35198123 0.        ]
# action and advantages :  [0. 1.] [0.        0.2813889]
# action and advantages :  [1. 0.] [0.21079656 0.        ]
# action and advantages :  [0. 1.] [0.         0.14020422]
# action and advantages :  [0. 1.] [0.         0.06961189]
# action and advantages :  [0. 1.] [-0.         -0.00098045]
# action and advantages :  [0. 1.] [-0.         -0.07157279]
# action and advantages :  [1. 0.] [-0.14216512 -0.        ]
# action and advantages :  [1. 0.] [-0.21275746 -0.        ]
# action and advantages :  [0. 1.] [-0.        -0.2833498]
# action and advantages :  [1. 0.] [-0.35394213 -0.        ]
# action and advantages :  [0. 1.] [-0.         -0.42453447]
# action and advantages :  [1. 0.] [-0.49512681 -0.        ]
# action and advantages :  [1. 0.] [-0.56571914 -0.        ]
# action and advantages :  [0. 1.] [-0.         -0.63631148]
# action and advantages :  [1. 0.] [-0.70690382 -0.        ]
# action and advantages :  [0. 1.] [-0.         -0.77749615]
# action and advantages :  [1. 0.] [-0.84808849 -0.        ]
# action and advantages :  [0. 1.] [-0.         -0.91868083]
# action and advantages :  [0. 1.] [-0.         -0.98927316]
# action and advantages :  [0. 1.] [-0.        -1.0598655]
# action and advantages :  [1. 0.] [-1.13045784 -0.        ]
# action and advantages :  [1. 0.] [-1.20105017 -0.        ]
# action and advantages :  [1. 0.] [-1.27164251 -0.        ]
# action and advantages :  [0. 1.] [-0.         -1.34223485]
# action and advantages :  [0. 1.] [-0.         -1.41282718]
# action and advantages :  [1. 0.] [-1.48341952 -0.        ]
# action and advantages :  [0. 1.] [-0.         -1.55401186]
# action and advantages :  [1. 0.] [-1.62460419 -0.        ]
# action and advantages :  [1. 0.] [-1.69519653 -0.        ]
# X_batch size :  (98, 80, 80, 4)
# Y_batch size :  (98, 2)
# using batch_size =  96
# creating: createPGCriterion
# creating: createRMSprop
# creating: createMaxIteration
# creating: createDistriOptimizer
# (80, 80, 4)
# living steps :  2
# living steps :  3
# living steps :  4
# living steps :  5
# living steps :  6
# living steps :  7
# living steps :  8
# living steps :  9
# living steps :  10
# living steps :  11
# living steps :  12
# living steps :  13
# living steps :  14
# living steps :  15
# living steps :  16
# living steps :  17
# living steps :  18
# living steps :  19
# (80, 80, 4)
# living steps :  2
# living steps :  3
# living steps :  4
# living steps :  5
# living steps :  6
# living steps :  7
# living steps :  8
# living steps :  9
# living steps :  10
# living steps :  11
# living steps :  12
# living steps :  13
# living steps :  14
# living steps :  15
# living steps :  16
# living steps :  17
# living steps :  18
# living steps :  19
# reward mean 0.7000000000000002
# reward std 0.0
# reward max 0.7000000000000002
# (80, 80, 4)
# living steps :  2
# living steps :  3
# living steps :  4
# living steps :  5
# living steps :  6
# living steps :  7
# living steps :  8
# living steps :  9
# living steps :  10
# living steps :  11
# living steps :  12
# living steps :  13
# living steps :  14
# living steps :  15
# living steps :  16
# living steps :  17
# living steps :  18
# living steps :  19
# (80, 80, 4)
# living steps :  2
# living steps :  3
# living steps :  4
# living steps :  5
# living steps :  6
# living steps :  7
# living steps :  8
# living steps :  9
# living steps :  10
# living steps :  11
# living steps :  12
# living steps :  13
# living steps :  14
# living steps :  15
# living steps :  16
# living steps :  17
# living steps :  18
# living steps :  19
# reward mean 0.7000000000000002
# reward std 0.0
# reward max 0.7000000000000002
# used in training:  4 - 6
# num of total steps in training  72
# training begin
# action and advantages :  [1. 0.] [1.65345367 0.        ]
# action and advantages :  [1. 0.] [1.44352883 0.        ]
# action and advantages :  [1. 0.] [1.24940246 0.        ]
# action and advantages :  [1. 0.] [1.05685594 0.        ]
# action and advantages :  [1. 0.] [0.86446741 0.        ]
# action and advantages :  [1. 0.] [0.67209467 0.        ]
# action and advantages :  [1. 0.] [0.47972351 0.        ]
# action and advantages :  [1. 0.] [0.28735251 0.        ]
# action and advantages :  [1. 0.] [0.09498152 0.        ]
# action and advantages :  [1. 0.] [-0.09738946 -0.        ]
# action and advantages :  [1. 0.] [-0.28976044 -0.        ]
# action and advantages :  [1. 0.] [-0.48213142 -0.        ]
# action and advantages :  [1. 0.] [-0.67450241 -0.        ]
# action and advantages :  [1. 0.] [-0.86687339 -0.        ]
# action and advantages :  [1. 0.] [-1.05924437 -0.        ]
# action and advantages :  [1. 0.] [-1.25161536 -0.        ]
# action and advantages :  [1. 0.] [-1.44398634 -0.        ]
# action and advantages :  [1. 0.] [-1.63635732 -0.        ]
# action and advantages :  [1. 0.] [1.67174455 0.        ]
# action and advantages :  [1. 0.] [1.44097344 0.        ]
# action and advantages :  [1. 0.] [1.24517782 0.        ]
# action and advantages :  [1. 0.] [1.05287975 0.        ]
# action and advantages :  [1. 0.] [0.86093144 0.        ]
# action and advantages :  [1. 0.] [0.6690181 0.       ]
# action and advantages :  [1. 0.] [0.47710826 0.        ]
# action and advantages :  [1. 0.] [0.28519877 0.        ]
# action and advantages :  [1. 0.] [0.09328932 0.        ]
# action and advantages :  [1. 0.] [-0.09862013 -0.        ]
# action and advantages :  [1. 0.] [-0.29052959 -0.        ]
# action and advantages :  [1. 0.] [-0.48243904 -0.        ]
# action and advantages :  [1. 0.] [-0.67434849 -0.        ]
# action and advantages :  [1. 0.] [-0.86625794 -0.        ]
# action and advantages :  [1. 0.] [-1.05816739 -0.        ]
# action and advantages :  [1. 0.] [-1.25007684 -0.        ]
# action and advantages :  [1. 0.] [-1.4419863 -0.       ]
# action and advantages :  [1. 0.] [-1.63389575 -0.        ]
# action and advantages :  [1. 0.] [1.67174455 0.        ]
# action and advantages :  [1. 0.] [1.44097344 0.        ]
# action and advantages :  [1. 0.] [1.24517782 0.        ]
# action and advantages :  [1. 0.] [1.05287975 0.        ]
# action and advantages :  [1. 0.] [0.86093144 0.        ]
# action and advantages :  [1. 0.] [0.6690181 0.       ]
# action and advantages :  [1. 0.] [0.47710826 0.        ]
# action and advantages :  [1. 0.] [0.28519877 0.        ]
# action and advantages :  [1. 0.] [0.09328932 0.        ]
# action and advantages :  [1. 0.] [-0.09862013 -0.        ]
# action and advantages :  [1. 0.] [-0.29052959 -0.        ]
# action and advantages :  [1. 0.] [-0.48243904 -0.        ]
# action and advantages :  [1. 0.] [-0.67434849 -0.        ]
# action and advantages :  [1. 0.] [-0.86625794 -0.        ]
# action and advantages :  [1. 0.] [-1.05816739 -0.        ]
# action and advantages :  [1. 0.] [-1.25007684 -0.        ]
# action and advantages :  [1. 0.] [-1.4419863 -0.       ]
# action and advantages :  [1. 0.] [-1.63389575 -0.        ]
# action and advantages :  [1. 0.] [1.67174455 0.        ]
# action and advantages :  [1. 0.] [1.44097344 0.        ]
# action and advantages :  [1. 0.] [1.24517782 0.        ]
# action and advantages :  [1. 0.] [1.05287975 0.        ]
# action and advantages :  [1. 0.] [0.86093144 0.        ]
# action and advantages :  [1. 0.] [0.6690181 0.       ]
# action and advantages :  [1. 0.] [0.47710826 0.        ]
# action and advantages :  [1. 0.] [0.28519877 0.        ]
# action and advantages :  [1. 0.] [0.09328932 0.        ]
# action and advantages :  [1. 0.] [-0.09862013 -0.        ]
# action and advantages :  [1. 0.] [-0.29052959 -0.        ]
# action and advantages :  [1. 0.] [-0.48243904 -0.        ]
# action and advantages :  [1. 0.] [-0.67434849 -0.        ]
# action and advantages :  [1. 0.] [-0.86625794 -0.        ]
# action and advantages :  [1. 0.] [-1.05816739 -0.        ]
# action and advantages :  [1. 0.] [-1.25007684 -0.        ]
# action and advantages :  [1. 0.] [-1.4419863 -0.       ]
# action and advantages :  [1. 0.] [-1.63389575 -0.        ]
# X_batch size :  (72, 80, 80, 4)
# Y_batch size :  (72, 2)
# using batch_size =  72
# creating: createPGCriterion
# creating: createRMSprop
# creating: createMaxIteration
# creating: createDistriOptimizer
# (80, 80, 4)
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:31: RuntimeWarning: invalid value encountered in less
# living steps :  2
# living steps :  3
# living steps :  4
# living steps :  5
# living steps :  6
# living steps :  7
# living steps :  8
# living steps :  9
# living steps :  10
# living steps :  11
# living steps :  12
# living steps :  13
# *********** Random Action *********** :  1
# living steps :  14
# living steps :  15
# living steps :  16
# living steps :  17
# living steps :  18
# living steps :  19
# living steps :  20
# living steps :  21
# living steps :  22
# living steps :  23
# living steps :  24
# living steps :  25
# living steps :  26
# living steps :  27
# living steps :  28
# living steps :  29
# living steps :  30
# living steps :  31
# living steps :  32
# living steps :  33
# living steps :  34
# living steps :  35
# living steps :  36
# living steps :  37
# living steps :  38
# (80, 80, 4)
# living steps :  2
# living steps :  3
# living steps :  4
# living steps :  5
# *********** Random Action *********** :  0
# living steps :  6
# living steps :  7
# living steps :  8
# living steps :  9
# living steps :  10
# living steps :  11
# living steps :  12
# living steps :  13
# living steps :  14
# living steps :  15
# living steps :  16
# living steps :  17
# living steps :  18
# living steps :  19
# reward mean 1.6500000000000004
# reward std 0.9500000000000002
# reward max 2.6000000000000005
# (80, 80, 4)
# living steps :  2
# living steps :  3
# living steps :  4
# living steps :  5
# living steps :  6
# living steps :  7
# living steps :  8
# living steps :  9
# living steps :  10
# living steps :  11
# living steps :  12
# living steps :  13
# living steps :  14
# living steps :  15
# living steps :  16
# living steps :  17
# living steps :  18
# living steps :  19
# (80, 80, 4)
# living steps :  2
# living steps :  3
# living steps :  4
# living steps :  5
# living steps :  6
# living steps :  7
# living steps :  8
# living steps :  9
# living steps :  10
# living steps :  11
# living steps :  12
# living steps :  13
# living steps :  14
# living steps :  15
# living steps :  16
# living steps :  17
# living steps :  18
# living steps :  19
# reward mean 0.7000000000000002
# reward std 0.0
# reward max 0.7000000000000002
# used in training:  8 - 10
# num of total steps in training  91
# training begin
# action and advantages :  [1. 0.] [1.71388359 0.        ]
# action and advantages :  [1. 0.] [1.59185548 0.        ]
# action and advantages :  [1. 0.] [1.49549535 0.        ]
# action and advantages :  [1. 0.] [1.40170202 0.        ]
# action and advantages :  [1. 0.] [1.30816537 0.        ]
# action and advantages :  [1. 0.] [1.21465439 0.        ]
# action and advantages :  [1. 0.] [1.12114597 0.        ]
# action and advantages :  [1. 0.] [1.02763781 0.        ]
# action and advantages :  [1. 0.] [0.93412968 0.        ]
# action and advantages :  [1. 0.] [0.84062155 0.        ]
# action and advantages :  [1. 0.] [0.74711342 0.        ]
# action and advantages :  [1. 0.] [0.65360529 0.        ]
# action and advantages :  [0. 1.] [0.         0.56009716]
# action and advantages :  [1. 0.] [0.46658903 0.        ]
# action and advantages :  [1. 0.] [0.3730809 0.       ]
# action and advantages :  [1. 0.] [0.27957277 0.        ]
# action and advantages :  [1. 0.] [0.18606464 0.        ]
# action and advantages :  [1. 0.] [0.09255651 0.        ]
# action and advantages :  [1. 0.] [-0.00095162 -0.        ]
# action and advantages :  [1. 0.] [-0.09445975 -0.        ]
# action and advantages :  [1. 0.] [-0.18796788 -0.        ]
# action and advantages :  [1. 0.] [-0.28147601 -0.        ]
# action and advantages :  [1. 0.] [-0.37498414 -0.        ]
# action and advantages :  [1. 0.] [-0.46849227 -0.        ]
# action and advantages :  [1. 0.] [-0.5620004 -0.       ]
# action and advantages :  [1. 0.] [-0.65550853 -0.        ]
# action and advantages :  [1. 0.] [-0.74901666 -0.        ]
# action and advantages :  [1. 0.] [-0.84252479 -0.        ]
# action and advantages :  [1. 0.] [-0.93603292 -0.        ]
# action and advantages :  [1. 0.] [-1.02954105 -0.        ]
# action and advantages :  [1. 0.] [-1.12304918 -0.        ]
# action and advantages :  [1. 0.] [-1.21655731 -0.        ]
# action and advantages :  [1. 0.] [-1.31006544 -0.        ]
# action and advantages :  [1. 0.] [-1.40357357 -0.        ]
# action and advantages :  [1. 0.] [-1.4970817 -0.       ]
# action and advantages :  [1. 0.] [-1.59058983 -0.        ]
# action and advantages :  [1. 0.] [-1.68409796 -0.        ]
# action and advantages :  [1. 0.] [1.67174455 0.        ]
# action and advantages :  [1. 0.] [1.44097344 0.        ]
# action and advantages :  [1. 0.] [1.24517782 0.        ]
# action and advantages :  [1. 0.] [1.05287975 0.        ]
# action and advantages :  [1. 0.] [0.86093144 0.        ]
# action and advantages :  [1. 0.] [0.6690181 0.       ]
# action and advantages :  [1. 0.] [0.47710826 0.        ]
# action and advantages :  [1. 0.] [0.28519877 0.        ]
# action and advantages :  [1. 0.] [0.09328932 0.        ]
# action and advantages :  [1. 0.] [-0.09862013 -0.        ]
# action and advantages :  [1. 0.] [-0.29052959 -0.        ]
# action and advantages :  [1. 0.] [-0.48243904 -0.        ]
# action and advantages :  [1. 0.] [-0.67434849 -0.        ]
# action and advantages :  [1. 0.] [-0.86625794 -0.        ]
# action and advantages :  [1. 0.] [-1.05816739 -0.        ]
# action and advantages :  [1. 0.] [-1.25007684 -0.        ]
# action and advantages :  [1. 0.] [-1.4419863 -0.       ]
# action and advantages :  [1. 0.] [-1.63389575 -0.        ]
# action and advantages :  [1. 0.] [1.67174455 0.        ]
# action and advantages :  [1. 0.] [1.44097344 0.        ]
# action and advantages :  [1. 0.] [1.24517782 0.        ]
# action and advantages :  [1. 0.] [1.05287975 0.        ]
# action and advantages :  [1. 0.] [0.86093144 0.        ]
# action and advantages :  [1. 0.] [0.6690181 0.       ]
# action and advantages :  [1. 0.] [0.47710826 0.        ]
# action and advantages :  [1. 0.] [0.28519877 0.        ]
# action and advantages :  [1. 0.] [0.09328932 0.        ]
# action and advantages :  [1. 0.] [-0.09862013 -0.        ]
# action and advantages :  [1. 0.] [-0.29052959 -0.        ]
# action and advantages :  [1. 0.] [-0.48243904 -0.        ]
# action and advantages :  [1. 0.] [-0.67434849 -0.        ]
# action and advantages :  [1. 0.] [-0.86625794 -0.        ]
# action and advantages :  [1. 0.] [-1.05816739 -0.        ]
# action and advantages :  [1. 0.] [-1.25007684 -0.        ]
# action and advantages :  [1. 0.] [-1.4419863 -0.       ]
# action and advantages :  [1. 0.] [-1.63389575 -0.        ]
# action and advantages :  [1. 0.] [1.67174455 0.        ]
# action and advantages :  [1. 0.] [1.44097344 0.        ]
# action and advantages :  [1. 0.] [1.24517782 0.        ]
# action and advantages :  [1. 0.] [1.05287975 0.        ]
# action and advantages :  [1. 0.] [0.86093144 0.        ]
# action and advantages :  [1. 0.] [0.6690181 0.       ]
# action and advantages :  [1. 0.] [0.47710826 0.        ]
# action and advantages :  [1. 0.] [0.28519877 0.        ]
# action and advantages :  [1. 0.] [0.09328932 0.        ]
# action and advantages :  [1. 0.] [-0.09862013 -0.        ]
# action and advantages :  [1. 0.] [-0.29052959 -0.        ]
# action and advantages :  [1. 0.] [-0.48243904 -0.        ]
# action and advantages :  [1. 0.] [-0.67434849 -0.        ]
# action and advantages :  [1. 0.] [-0.86625794 -0.        ]
# action and advantages :  [1. 0.] [-1.05816739 -0.        ]
# action and advantages :  [1. 0.] [-1.25007684 -0.        ]
# action and advantages :  [1. 0.] [-1.4419863 -0.       ]
# action and advantages :  [1. 0.] [-1.63389575 -0.        ]
# X_batch size :  (91, 80, 80, 4)
# Y_batch size :  (91, 2)
# using batch_size =  88
# creating: createPGCriterion
# creating: createRMSprop
# creating: createMaxIteration
# creating: createDistriOptimizer
# (80, 80, 4)
# living steps :  2
# living steps :  3
# living steps :  4
# living steps :  5
# living steps :  6
# living steps :  7
# living steps :  8
# living steps :  9
# living steps :  10
# living steps :  11
# living steps :  12
# living steps :  13
# living steps :  14
# living steps :  15
# living steps :  16
# living steps :  17
# living steps :  18
# living steps :  19
# (80, 80, 4)
# living steps :  2
# living steps :  3
# living steps :  4
# living steps :  5
# living steps :  6
# living steps :  7
# living steps :  8
# living steps :  9
# living steps :  10
# living steps :  11
# living steps :  12
# living steps :  13
# living steps :  14
# living steps :  15
# living steps :  16
# living steps :  17
# living steps :  18
# living steps :  19
# reward mean 0.7000000000000002
# reward std 0.0
# reward max 0.7000000000000002
# (80, 80, 4)
# living steps :  2
# living steps :  3
# living steps :  4
# living steps :  5
# living steps :  6
# living steps :  7
# living steps :  8
# living steps :  9
# living steps :  10
# living steps :  11
# living steps :  12
# living steps :  13
# living steps :  14
# living steps :  15
# living steps :  16
# living steps :  17
# living steps :  18
# *********** Random Action *********** :  1
# living steps :  19
# living steps :  20
# living steps :  21
# living steps :  22
# living steps :  23
# living steps :  24
# living steps :  25
# living steps :  26
# living steps :  27
# living steps :  28
# living steps :  29
# living steps :  30
# living steps :  31
# living steps :  32
# living steps :  33
# living steps :  34
# living steps :  35
# living steps :  36
# living steps :  37
# living steps :  38
# (80, 80, 4)
# living steps :  2
# living steps :  3
# living steps :  4
# living steps :  5
# living steps :  6
# living steps :  7
# living steps :  8
# living steps :  9
# living steps :  10
# living steps :  11
# living steps :  12
# living steps :  13
# living steps :  14
# living steps :  15
# living steps :  16
# living steps :  17
# living steps :  18
# living steps :  19
# reward mean 1.6500000000000004
# reward std 0.9500000000000002
# reward max 2.6000000000000005
# used in training:  12 - 14
# num of total steps in training  91
# training begin
# action and advantages :  [1. 0.] [1.65345367 0.        ]
# action and advantages :  [1. 0.] [1.44352883 0.        ]
# action and advantages :  [1. 0.] [1.24940246 0.        ]
# action and advantages :  [1. 0.] [1.05685594 0.        ]
# action and advantages :  [1. 0.] [0.86446741 0.        ]
# action and advantages :  [1. 0.] [0.67209467 0.        ]
# action and advantages :  [1. 0.] [0.47972351 0.        ]
# action and advantages :  [1. 0.] [0.28735251 0.        ]
# action and advantages :  [1. 0.] [0.09498152 0.        ]
# action and advantages :  [1. 0.] [-0.09738946 -0.        ]
# action and advantages :  [1. 0.] [-0.28976044 -0.        ]
# action and advantages :  [1. 0.] [-0.48213142 -0.        ]
# action and advantages :  [1. 0.] [-0.67450241 -0.        ]
# action and advantages :  [1. 0.] [-0.86687339 -0.        ]
# action and advantages :  [1. 0.] [-1.05924437 -0.        ]
# action and advantages :  [1. 0.] [-1.25161536 -0.        ]
# action and advantages :  [1. 0.] [-1.44398634 -0.        ]
# action and advantages :  [1. 0.] [-1.63635732 -0.        ]
# action and advantages :  [1. 0.] [1.67174455 0.        ]
# action and advantages :  [1. 0.] [1.44097344 0.        ]
# action and advantages :  [1. 0.] [1.24517782 0.        ]
# action and advantages :  [1. 0.] [1.05287975 0.        ]
# action and advantages :  [1. 0.] [0.86093144 0.        ]
# action and advantages :  [1. 0.] [0.6690181 0.       ]
# action and advantages :  [1. 0.] [0.47710826 0.        ]
# action and advantages :  [1. 0.] [0.28519877 0.        ]
# action and advantages :  [1. 0.] [0.09328932 0.        ]
# action and advantages :  [1. 0.] [-0.09862013 -0.        ]
# action and advantages :  [1. 0.] [-0.29052959 -0.        ]
# action and advantages :  [1. 0.] [-0.48243904 -0.        ]
# action and advantages :  [1. 0.] [-0.67434849 -0.        ]
# action and advantages :  [1. 0.] [-0.86625794 -0.        ]
# action and advantages :  [1. 0.] [-1.05816739 -0.        ]
# action and advantages :  [1. 0.] [-1.25007684 -0.        ]
# action and advantages :  [1. 0.] [-1.4419863 -0.       ]
# action and advantages :  [1. 0.] [-1.63389575 -0.        ]
# action and advantages :  [1. 0.] [1.72407468 0.        ]
# action and advantages :  [1. 0.] [1.59172212 0.        ]
# action and advantages :  [1. 0.] [1.49437933 0.        ]
# action and advantages :  [1. 0.] [1.40053752 0.        ]
# action and advantages :  [1. 0.] [1.3070458 0.       ]
# action and advantages :  [1. 0.] [1.2135891 0.       ]
# action and advantages :  [1. 0.] [1.12013589 0.        ]
# action and advantages :  [1. 0.] [1.02668303 0.        ]
# action and advantages :  [1. 0.] [0.93323021 0.        ]
# action and advantages :  [1. 0.] [0.8397774 0.       ]
# action and advantages :  [1. 0.] [0.74632458 0.        ]
# action and advantages :  [1. 0.] [0.65287176 0.        ]
# action and advantages :  [1. 0.] [0.55941895 0.        ]
# action and advantages :  [1. 0.] [0.46596613 0.        ]
# action and advantages :  [1. 0.] [0.37251331 0.        ]
# action and advantages :  [1. 0.] [0.27906049 0.        ]
# action and advantages :  [1. 0.] [0.18560768 0.        ]
# action and advantages :  [0. 1.] [0.         0.09215486]
# action and advantages :  [1. 0.] [-0.00129796 -0.        ]
# action and advantages :  [1. 0.] [-0.09475077 -0.        ]
# action and advantages :  [1. 0.] [-0.18820359 -0.        ]
# action and advantages :  [1. 0.] [-0.28165641 -0.        ]
# action and advantages :  [1. 0.] [-0.37510922 -0.        ]
# action and advantages :  [1. 0.] [-0.46856204 -0.        ]
# action and advantages :  [1. 0.] [-0.56201486 -0.        ]
# action and advantages :  [1. 0.] [-0.65546767 -0.        ]
# action and advantages :  [1. 0.] [-0.74892049 -0.        ]
# action and advantages :  [1. 0.] [-0.84237331 -0.        ]
# action and advantages :  [1. 0.] [-0.93582612 -0.        ]
# action and advantages :  [1. 0.] [-1.02927894 -0.        ]
# action and advantages :  [1. 0.] [-1.12273176 -0.        ]
# action and advantages :  [1. 0.] [-1.21618458 -0.        ]
# action and advantages :  [1. 0.] [-1.30963739 -0.        ]
# action and advantages :  [1. 0.] [-1.40309021 -0.        ]
# action and advantages :  [1. 0.] [-1.49654303 -0.        ]
# action and advantages :  [1. 0.] [-1.58999584 -0.        ]
# action and advantages :  [1. 0.] [-1.68344866 -0.        ]
# action and advantages :  [1. 0.] [1.67174455 0.        ]
# action and advantages :  [1. 0.] [1.44097344 0.        ]
# action and advantages :  [1. 0.] [1.24517782 0.        ]
# action and advantages :  [1. 0.] [1.05287975 0.        ]
# action and advantages :  [1. 0.] [0.86093144 0.        ]
# action and advantages :  [1. 0.] [0.6690181 0.       ]
# action and advantages :  [1. 0.] [0.47710826 0.        ]
# action and advantages :  [1. 0.] [0.28519877 0.        ]
# action and advantages :  [1. 0.] [0.09328932 0.        ]
# action and advantages :  [1. 0.] [-0.09862013 -0.        ]
# action and advantages :  [1. 0.] [-0.29052959 -0.        ]
# action and advantages :  [1. 0.] [-0.48243904 -0.        ]
# action and advantages :  [1. 0.] [-0.67434849 -0.        ]
# action and advantages :  [1. 0.] [-0.86625794 -0.        ]
# action and advantages :  [1. 0.] [-1.05816739 -0.        ]
# action and advantages :  [1. 0.] [-1.25007684 -0.        ]
# action and advantages :  [1. 0.] [-1.4419863 -0.       ]
# action and advantages :  [1. 0.] [-1.63389575 -0.        ]
# X_batch size :  (91, 80, 80, 4)
# Y_batch size :  (91, 2)
# using batch_size =  88
# creating: createPGCriterion
# creating: createRMSprop
# creating: createMaxIteration
# creating: createDistriOptimizer
# (80, 80, 4)
# living steps :  2
# living steps :  3
# living steps :  4
# living steps :  5
# living steps :  6
# living steps :  7
# living steps :  8
# living steps :  9
# living steps :  10
# living steps :  11
# living steps :  12
# living steps :  13
# living steps :  14
# living steps :  15
# living steps :  16
# living steps :  17
# living steps :  18
# living steps :  19
# (80, 80, 4)
# living steps :  2
# living steps :  3
# living steps :  4
# living steps :  5
# living steps :  6
# living steps :  7
# living steps :  8
# living steps :  9
# living steps :  10
# living steps :  11
# living steps :  12
# living steps :  13
# living steps :  14
# living steps :  15
# living steps :  16
# living steps :  17
# living steps :  18
# living steps :  19
# reward mean 0.7000000000000002
# reward std 0.0
# reward max 0.7000000000000002
# (80, 80, 4)
# living steps :  2
# living steps :  3
# living steps :  4
# living steps :  5
# living steps :  6
# living steps :  7
# living steps :  8
# living steps :  9
# living steps :  10
# living steps :  11
# living steps :  12
# living steps :  13
# living steps :  14
# *********** Random Action *********** :  1
# living steps :  15
# living steps :  16
# living steps :  17
# living steps :  18
# living steps :  19
# living steps :  20
# living steps :  21
# living steps :  22
# living steps :  23
# living steps :  24
# living steps :  25
# living steps :  26
# *********** Random Action *********** :  0
# living steps :  27
# living steps :  28
# living steps :  29
# living steps :  30
# *********** Random Action *********** :  1
# living steps :  31
# living steps :  32
# living steps :  33
# living steps :  34
# living steps :  35
# living steps :  36
# living steps :  37
# living steps :  38
# living steps :  39
# living steps :  40
# living steps :  41
# living steps :  42
# living steps :  43
# living steps :  44
# living steps :  45
# living steps :  46
# living steps :  47
# *********** Random Action *********** :  1
# living steps :  48
# living steps :  49
# living steps :  50
# (80, 80, 4)
# living steps :  2
# living steps :  3
# living steps :  4
# living steps :  5
# living steps :  6
# living steps :  7
# living steps :  8
# living steps :  9
# living steps :  10
# living steps :  11
# living steps :  12
# living steps :  13
# living steps :  14
# living steps :  15
# living steps :  16
# living steps :  17
# living steps :  18
# living steps :  19
# reward mean 2.25
# reward std 1.5499999999999998
# reward max 3.8
# used in training:  16 - 18
# num of total steps in training  103
# training begin
# action and advantages :  [1. 0.] [1.65345367 0.        ]
# action and advantages :  [1. 0.] [1.44352883 0.        ]
# action and advantages :  [1. 0.] [1.24940246 0.        ]
# action and advantages :  [1. 0.] [1.05685594 0.        ]
# action and advantages :  [1. 0.] [0.86446741 0.        ]
# action and advantages :  [1. 0.] [0.67209467 0.        ]
# action and advantages :  [1. 0.] [0.47972351 0.        ]
# action and advantages :  [1. 0.] [0.28735251 0.        ]
# action and advantages :  [1. 0.] [0.09498152 0.        ]
# action and advantages :  [1. 0.] [-0.09738946 -0.        ]
# action and advantages :  [1. 0.] [-0.28976044 -0.        ]
# action and advantages :  [1. 0.] [-0.48213142 -0.        ]
# action and advantages :  [1. 0.] [-0.67450241 -0.        ]
# action and advantages :  [1. 0.] [-0.86687339 -0.        ]
# action and advantages :  [1. 0.] [-1.05924437 -0.        ]
# action and advantages :  [1. 0.] [-1.25161536 -0.        ]
# action and advantages :  [1. 0.] [-1.44398634 -0.        ]
# action and advantages :  [1. 0.] [-1.63635732 -0.        ]
# action and advantages :  [1. 0.] [1.67174455 0.        ]
# action and advantages :  [1. 0.] [1.44097344 0.        ]
# action and advantages :  [1. 0.] [1.24517782 0.        ]
# action and advantages :  [1. 0.] [1.05287975 0.        ]
# action and advantages :  [1. 0.] [0.86093144 0.        ]
# action and advantages :  [1. 0.] [0.6690181 0.       ]
# action and advantages :  [1. 0.] [0.47710826 0.        ]
# action and advantages :  [1. 0.] [0.28519877 0.        ]
# action and advantages :  [1. 0.] [0.09328932 0.        ]
# action and advantages :  [1. 0.] [-0.09862013 -0.        ]
# action and advantages :  [1. 0.] [-0.29052959 -0.        ]
# action and advantages :  [1. 0.] [-0.48243904 -0.        ]
# action and advantages :  [1. 0.] [-0.67434849 -0.        ]
# action and advantages :  [1. 0.] [-0.86625794 -0.        ]
# action and advantages :  [1. 0.] [-1.05816739 -0.        ]
# action and advantages :  [1. 0.] [-1.25007684 -0.        ]
# action and advantages :  [1. 0.] [-1.4419863 -0.       ]
# action and advantages :  [1. 0.] [-1.63389575 -0.        ]
# action and advantages :  [1. 0.] [1.73647344 0.        ]
# action and advantages :  [1. 0.] [1.62696708 0.        ]
# action and advantages :  [1. 0.] [1.55248334 0.        ]
# action and advantages :  [1. 0.] [1.48150186 0.        ]
# action and advantages :  [1. 0.] [1.41087061 0.        ]
# action and advantages :  [1. 0.] [1.34027438 0.        ]
# action and advantages :  [1. 0.] [1.26968166 0.        ]
# action and advantages :  [1. 0.] [1.19908928 0.        ]
# action and advantages :  [1. 0.] [1.12849694 0.        ]
# action and advantages :  [1. 0.] [1.0579046 0.       ]
# action and advantages :  [1. 0.] [0.98731227 0.        ]
# action and advantages :  [1. 0.] [0.91671993 0.        ]
# action and advantages :  [1. 0.] [0.84612759 0.        ]
# action and advantages :  [0. 1.] [0.         0.77553526]
# action and advantages :  [1. 0.] [0.70494292 0.        ]
# action and advantages :  [1. 0.] [0.63435058 0.        ]
# action and advantages :  [1. 0.] [0.56375824 0.        ]
# action and advantages :  [1. 0.] [0.49316591 0.        ]
# action and advantages :  [1. 0.] [0.42257357 0.        ]
# action and advantages :  [1. 0.] [0.35198123 0.        ]
# action and advantages :  [1. 0.] [0.2813889 0.       ]
# action and advantages :  [1. 0.] [0.21079656 0.        ]
# action and advantages :  [1. 0.] [0.14020422 0.        ]
# action and advantages :  [1. 0.] [0.06961189 0.        ]
# action and advantages :  [1. 0.] [-0.00098045 -0.        ]
# action and advantages :  [1. 0.] [-0.07157279 -0.        ]
# action and advantages :  [1. 0.] [-0.14216512 -0.        ]
# action and advantages :  [1. 0.] [-0.21275746 -0.        ]
# action and advantages :  [1. 0.] [-0.2833498 -0.       ]
# action and advantages :  [0. 1.] [-0.         -0.35394213]
# action and advantages :  [1. 0.] [-0.42453447 -0.        ]
# action and advantages :  [1. 0.] [-0.49512681 -0.        ]
# action and advantages :  [1. 0.] [-0.56571914 -0.        ]
# action and advantages :  [1. 0.] [-0.63631148 -0.        ]
# action and advantages :  [1. 0.] [-0.70690382 -0.        ]
# action and advantages :  [1. 0.] [-0.77749615 -0.        ]
# action and advantages :  [1. 0.] [-0.84808849 -0.        ]
# action and advantages :  [1. 0.] [-0.91868083 -0.        ]
# action and advantages :  [1. 0.] [-0.98927316 -0.        ]
# action and advantages :  [1. 0.] [-1.0598655 -0.       ]
# action and advantages :  [1. 0.] [-1.13045784 -0.        ]
# action and advantages :  [1. 0.] [-1.20105017 -0.        ]
# action and advantages :  [1. 0.] [-1.27164251 -0.        ]
# action and advantages :  [1. 0.] [-1.34223485 -0.        ]
# action and advantages :  [1. 0.] [-1.41282718 -0.        ]
# action and advantages :  [1. 0.] [-1.48341952 -0.        ]
# action and advantages :  [0. 1.] [-0.         -1.55401186]
# action and advantages :  [1. 0.] [-1.62460419 -0.        ]
# action and advantages :  [1. 0.] [-1.69519653 -0.        ]
# action and advantages :  [1. 0.] [1.67174455 0.        ]
# action and advantages :  [1. 0.] [1.44097344 0.        ]
# action and advantages :  [1. 0.] [1.24517782 0.        ]
# action and advantages :  [1. 0.] [1.05287975 0.        ]
# action and advantages :  [1. 0.] [0.86093144 0.        ]
# action and advantages :  [1. 0.] [0.6690181 0.       ]
# action and advantages :  [1. 0.] [0.47710826 0.        ]
# action and advantages :  [1. 0.] [0.28519877 0.        ]
# action and advantages :  [1. 0.] [0.09328932 0.        ]
# action and advantages :  [1. 0.] [-0.09862013 -0.        ]
# action and advantages :  [1. 0.] [-0.29052959 -0.        ]
# action and advantages :  [1. 0.] [-0.48243904 -0.        ]
# action and advantages :  [1. 0.] [-0.67434849 -0.        ]
# action and advantages :  [1. 0.] [-0.86625794 -0.        ]
# action and advantages :  [1. 0.] [-1.05816739 -0.        ]
# action and advantages :  [1. 0.] [-1.25007684 -0.        ]
# action and advantages :  [1. 0.] [-1.4419863 -0.       ]
# action and advantages :  [1. 0.] [-1.63389575 -0.        ]
# X_batch size :  (103, 80, 80, 4)
# Y_batch size :  (103, 2)
# using batch_size =  96
# creating: createPGCriterion
# creating: createRMSprop
# creating: createMaxIteration
# creating: createDistriOptimizer
# (80, 80, 4)
# living steps :  2
# living steps :  3
# living steps :  4
# living steps :  5
# living steps :  6
# living steps :  7
# living steps :  8
# living steps :  9
# living steps :  10
# living steps :  11
# living steps :  12
# living steps :  13
# living steps :  14
# living steps :  15
# living steps :  16
# living steps :  17
# living steps :  18
# living steps :  19
# (80, 80, 4)
# living steps :  2
# living steps :  3
# living steps :  4
# living steps :  5
# living steps :  6
# living steps :  7
# living steps :  8
# living steps :  9
# living steps :  10
# living steps :  11
# living steps :  12
# living steps :  13
# living steps :  14
# living steps :  15
# living steps :  16
# living steps :  17
# living steps :  18
# living steps :  19
# reward mean 0.7000000000000002
# reward std 0.0
# reward max 0.7000000000000002
# (80, 80, 4)
# living steps :  2
# living steps :  3
# living steps :  4
# living steps :  5
# living steps :  6
# living steps :  7
# living steps :  8
# living steps :  9
# living steps :  10
# living steps :  11
# living steps :  12
# living steps :  13
# living steps :  14
# living steps :  15
# living steps :  16
# living steps :  17
# living steps :  18
# living steps :  19
# (80, 80, 4)
# living steps :  2
# living steps :  3
# living steps :  4
# living steps :  5
# living steps :  6
# living steps :  7
# living steps :  8
# living steps :  9
# living steps :  10
# living steps :  11
# living steps :  12
# living steps :  13
# living steps :  14
# living steps :  15
# living steps :  16
# living steps :  17
# living steps :  18
# living steps :  19
# reward mean 0.7000000000000002
# reward std 0.0
# reward max 0.7000000000000002
# used in training:  20 - 22
# num of total steps in training  72
# training begin
# action and advantages :  [1. 0.] [1.65345367 0.        ]
# action and advantages :  [1. 0.] [1.44352883 0.        ]
# action and advantages :  [1. 0.] [1.24940246 0.        ]
# action and advantages :  [1. 0.] [1.05685594 0.        ]
# action and advantages :  [1. 0.] [0.86446741 0.        ]
# action and advantages :  [1. 0.] [0.67209467 0.        ]
# action and advantages :  [1. 0.] [0.47972351 0.        ]
# action and advantages :  [1. 0.] [0.28735251 0.        ]
# action and advantages :  [1. 0.] [0.09498152 0.        ]
# action and advantages :  [1. 0.] [-0.09738946 -0.        ]
# action and advantages :  [1. 0.] [-0.28976044 -0.        ]
# action and advantages :  [1. 0.] [-0.48213142 -0.        ]
# action and advantages :  [1. 0.] [-0.67450241 -0.        ]
# action and advantages :  [1. 0.] [-0.86687339 -0.        ]
# action and advantages :  [1. 0.] [-1.05924437 -0.        ]
# action and advantages :  [1. 0.] [-1.25161536 -0.        ]
# action and advantages :  [1. 0.] [-1.44398634 -0.        ]
# action and advantages :  [1. 0.] [-1.63635732 -0.        ]
# action and advantages :  [1. 0.] [1.67174455 0.        ]
# action and advantages :  [1. 0.] [1.44097344 0.        ]
# action and advantages :  [1. 0.] [1.24517782 0.        ]
# action and advantages :  [1. 0.] [1.05287975 0.        ]
# action and advantages :  [1. 0.] [0.86093144 0.        ]
# action and advantages :  [1. 0.] [0.6690181 0.       ]
# action and advantages :  [1. 0.] [0.47710826 0.        ]
# action and advantages :  [1. 0.] [0.28519877 0.        ]
# action and advantages :  [1. 0.] [0.09328932 0.        ]
# action and advantages :  [1. 0.] [-0.09862013 -0.        ]
# action and advantages :  [1. 0.] [-0.29052959 -0.        ]
# action and advantages :  [1. 0.] [-0.48243904 -0.        ]
# action and advantages :  [1. 0.] [-0.67434849 -0.        ]
# action and advantages :  [1. 0.] [-0.86625794 -0.        ]
# action and advantages :  [1. 0.] [-1.05816739 -0.        ]
# action and advantages :  [1. 0.] [-1.25007684 -0.        ]
# action and advantages :  [1. 0.] [-1.4419863 -0.       ]
# action and advantages :  [1. 0.] [-1.63389575 -0.        ]
# action and advantages :  [1. 0.] [1.67174455 0.        ]
# action and advantages :  [1. 0.] [1.44097344 0.        ]
# action and advantages :  [1. 0.] [1.24517782 0.        ]
# action and advantages :  [1. 0.] [1.05287975 0.        ]
# action and advantages :  [1. 0.] [0.86093144 0.        ]
# action and advantages :  [1. 0.] [0.6690181 0.       ]
# action and advantages :  [1. 0.] [0.47710826 0.        ]
# action and advantages :  [1. 0.] [0.28519877 0.        ]
# action and advantages :  [1. 0.] [0.09328932 0.        ]
# action and advantages :  [1. 0.] [-0.09862013 -0.        ]
# action and advantages :  [1. 0.] [-0.29052959 -0.        ]
# action and advantages :  [1. 0.] [-0.48243904 -0.        ]
# action and advantages :  [1. 0.] [-0.67434849 -0.        ]
# action and advantages :  [1. 0.] [-0.86625794 -0.        ]
# action and advantages :  [1. 0.] [-1.05816739 -0.        ]
# action and advantages :  [1. 0.] [-1.25007684 -0.        ]
# action and advantages :  [1. 0.] [-1.4419863 -0.       ]
# action and advantages :  [1. 0.] [-1.63389575 -0.        ]
# action and advantages :  [1. 0.] [1.67174455 0.        ]
# action and advantages :  [1. 0.] [1.44097344 0.        ]
# action and advantages :  [1. 0.] [1.24517782 0.        ]
# action and advantages :  [1. 0.] [1.05287975 0.        ]
# action and advantages :  [1. 0.] [0.86093144 0.        ]
# action and advantages :  [1. 0.] [0.6690181 0.       ]
# action and advantages :  [1. 0.] [0.47710826 0.        ]
# action and advantages :  [1. 0.] [0.28519877 0.        ]
# action and advantages :  [1. 0.] [0.09328932 0.        ]
# action and advantages :  [1. 0.] [-0.09862013 -0.        ]
# action and advantages :  [1. 0.] [-0.29052959 -0.        ]
# action and advantages :  [1. 0.] [-0.48243904 -0.        ]
# action and advantages :  [1. 0.] [-0.67434849 -0.        ]
# action and advantages :  [1. 0.] [-0.86625794 -0.        ]
# action and advantages :  [1. 0.] [-1.05816739 -0.        ]
# action and advantages :  [1. 0.] [-1.25007684 -0.        ]
# action and advantages :  [1. 0.] [-1.4419863 -0.       ]
# action and advantages :  [1. 0.] [-1.63389575 -0.        ]
# X_batch size :  (72, 80, 80, 4)
# Y_batch size :  (72, 2)
# using batch_size =  72
# creating: createPGCriterion
# creating: createRMSprop
# creating: createMaxIteration
# creating: createDistriOptimizer
# (80, 80, 4)
# living steps :  2
# living steps :  3
# living steps :  4
# living steps :  5
# living steps :  6
# living steps :  7
# living steps :  8
# living steps :  9
# living steps :  10
# living steps :  11
# living steps :  12
# living steps :  13
# living steps :  14
# living steps :  15
# living steps :  16
# living steps :  17
# living steps :  18
# living steps :  19
# (80, 80, 4)
# living steps :  2
# living steps :  3
# living steps :  4
# living steps :  5
# living steps :  6
# living steps :  7
# living steps :  8
# living steps :  9
# living steps :  10
# living steps :  11
# living steps :  12
# living steps :  13
# living steps :  14
# living steps :  15
# living steps :  16
# living steps :  17
# living steps :  18
# living steps :  19
# reward mean 0.7000000000000002
# reward std 0.0
# reward max 0.7000000000000002
# (80, 80, 4)
# living steps :  2
# living steps :  3
# living steps :  4
# living steps :  5
# living steps :  6
# living steps :  7
# living steps :  8
# living steps :  9
# living steps :  10
# living steps :  11
# living steps :  12
# living steps :  13
# living steps :  14
# living steps :  15
# living steps :  16
# living steps :  17
# living steps :  18
# living steps :  19
# (80, 80, 4)
# living steps :  2
# living steps :  3
# living steps :  4
# living steps :  5
# living steps :  6
# living steps :  7
# living steps :  8
# living steps :  9
# living steps :  10
# living steps :  11
# living steps :  12
# living steps :  13
# living steps :  14
# living steps :  15
# living steps :  16
# living steps :  17
# living steps :  18
# living steps :  19
# reward mean 0.7000000000000002
# reward std 0.0
# reward max 0.7000000000000002
# used in training:  24 - 26
# num of total steps in training  72
# training begin
# action and advantages :  [1. 0.] [1.65345367 0.        ]
# action and advantages :  [1. 0.] [1.44352883 0.        ]
# action and advantages :  [1. 0.] [1.24940246 0.        ]
# action and advantages :  [1. 0.] [1.05685594 0.        ]
# action and advantages :  [1. 0.] [0.86446741 0.        ]
# action and advantages :  [1. 0.] [0.67209467 0.        ]
# action and advantages :  [1. 0.] [0.47972351 0.        ]
# action and advantages :  [1. 0.] [0.28735251 0.        ]
# action and advantages :  [1. 0.] [0.09498152 0.        ]
# action and advantages :  [1. 0.] [-0.09738946 -0.        ]
# action and advantages :  [1. 0.] [-0.28976044 -0.        ]
# action and advantages :  [1. 0.] [-0.48213142 -0.        ]
# action and advantages :  [1. 0.] [-0.67450241 -0.        ]
# action and advantages :  [1. 0.] [-0.86687339 -0.        ]
# action and advantages :  [1. 0.] [-1.05924437 -0.        ]
# action and advantages :  [1. 0.] [-1.25161536 -0.        ]
# action and advantages :  [1. 0.] [-1.44398634 -0.        ]
# action and advantages :  [1. 0.] [-1.63635732 -0.        ]
# action and advantages :  [1. 0.] [1.67174455 0.        ]
# action and advantages :  [1. 0.] [1.44097344 0.        ]
# action and advantages :  [1. 0.] [1.24517782 0.        ]
# action and advantages :  [1. 0.] [1.05287975 0.        ]
# action and advantages :  [1. 0.] [0.86093144 0.        ]
# action and advantages :  [1. 0.] [0.6690181 0.       ]
# action and advantages :  [1. 0.] [0.47710826 0.        ]
# action and advantages :  [1. 0.] [0.28519877 0.        ]
# action and advantages :  [1. 0.] [0.09328932 0.        ]
# action and advantages :  [1. 0.] [-0.09862013 -0.        ]
# action and advantages :  [1. 0.] [-0.29052959 -0.        ]
# action and advantages :  [1. 0.] [-0.48243904 -0.        ]
# action and advantages :  [1. 0.] [-0.67434849 -0.        ]
# action and advantages :  [1. 0.] [-0.86625794 -0.        ]
# action and advantages :  [1. 0.] [-1.05816739 -0.        ]
# action and advantages :  [1. 0.] [-1.25007684 -0.        ]
# action and advantages :  [1. 0.] [-1.4419863 -0.       ]
# action and advantages :  [1. 0.] [-1.63389575 -0.        ]
# action and advantages :  [1. 0.] [1.67174455 0.        ]
# action and advantages :  [1. 0.] [1.44097344 0.        ]
# ...
# action and advantages :  [1. 0.] [0.67209467 0.        ]
# action and advantages :  [1. 0.] [0.47972351 0.        ]
# action and advantages :  [1. 0.] [0.28735251 0.        ]
# action and advantages :  [1. 0.] [0.09498152 0.        ]
# action and advantages :  [1. 0.] [-0.09738946 -0.        ]
# action and advantages :  [1. 0.] [-0.28976044 -0.        ]
# action and advantages :  [1. 0.] [-0.48213142 -0.        ]
# action and advantages :  [1. 0.] [-0.67450241 -0.        ]
# action and advantages :  [1. 0.] [-0.86687339 -0.        ]
# action and advantages :  [1. 0.] [-1.05924437 -0.        ]
# action and advantages :  [1. 0.] [-1.25161536 -0.        ]
# action and advantages :  [1. 0.] [-1.44398634 -0.        ]
# action and advantages :  [1. 0.] [-1.63635732 -0.        ]
# action and advantages :  [1. 0.] [1.67174455 0.        ]
# action and advantages :  [1. 0.] [1.44097344 0.        ]
# action and advantages :  [1. 0.] [1.24517782 0.        ]
# action and advantages :  [1. 0.] [1.05287975 0.        ]
# action and advantages :  [1. 0.] [0.86093144 0.        ]
# action and advantages :  [1. 0.] [0.6690181 0.       ]
# action and advantages :  [1. 0.] [0.47710826 0.        ]
# action and advantages :  [1. 0.] [0.28519877 0.        ]
# action and advantages :  [1. 0.] [0.09328932 0.        ]
# action and advantages :  [1. 0.] [-0.09862013 -0.        ]
# action and advantages :  [1. 0.] [-0.29052959 -0.        ]
# action and advantages :  [1. 0.] [-0.48243904 -0.        ]
# action and advantages :  [1. 0.] [-0.67434849 -0.        ]
# action and advantages :  [1. 0.] [-0.86625794 -0.        ]
# action and advantages :  [1. 0.] [-1.05816739 -0.        ]
# action and advantages :  [1. 0.] [-1.25007684 -0.        ]
# action and advantages :  [1. 0.] [-1.4419863 -0.       ]
# action and advantages :  [1. 0.] [-1.63389575 -0.        ]
# action and advantages :  [1. 0.] [1.67174455 0.        ]
# action and advantages :  [1. 0.] [1.44097344 0.        ]
# action and advantages :  [1. 0.] [1.24517782 0.        ]
# action and advantages :  [1. 0.] [1.05287975 0.        ]
# action and advantages :  [1. 0.] [0.86093144 0.        ]
# action and advantages :  [1. 0.] [0.6690181 0.       ]
# action and advantages :  [1. 0.] [0.47710826 0.        ]
# action and advantages :  [1. 0.] [0.28519877 0.        ]
# action and advantages :  [1. 0.] [0.09328932 0.        ]
# action and advantages :  [1. 0.] [-0.09862013 -0.        ]
# action and advantages :  [1. 0.] [-0.29052959 -0.        ]
# action and advantages :  [1. 0.] [-0.48243904 -0.        ]
# action and advantages :  [1. 0.] [-0.67434849 -0.        ]
# action and advantages :  [1. 0.] [-0.86625794 -0.        ]
# action and advantages :  [1. 0.] [-1.05816739 -0.        ]
# action and advantages :  [1. 0.] [-1.25007684 -0.        ]
# action and advantages :  [1. 0.] [-1.4419863 -0.       ]
# action and advantages :  [1. 0.] [-1.63389575 -0.        ]
# action and advantages :  [1. 0.] [1.67174455 0.        ]
# action and advantages :  [1. 0.] [1.44097344 0.        ]
# action and advantages :  [1. 0.] [1.24517782 0.        ]
# action and advantages :  [1. 0.] [1.05287975 0.        ]
# action and advantages :  [1. 0.] [0.86093144 0.        ]
# action and advantages :  [1. 0.] [0.6690181 0.       ]
# action and advantages :  [1. 0.] [0.47710826 0.        ]
# action and advantages :  [1. 0.] [0.28519877 0.        ]
# action and advantages :  [1. 0.] [0.09328932 0.        ]
# action and advantages :  [1. 0.] [-0.09862013 -0.        ]
# action and advantages :  [1. 0.] [-0.29052959 -0.        ]
# action and advantages :  [1. 0.] [-0.48243904 -0.        ]
# action and advantages :  [1. 0.] [-0.67434849 -0.        ]
# action and advantages :  [1. 0.] [-0.86625794 -0.        ]
# action and advantages :  [1. 0.] [-1.05816739 -0.        ]
# action and advantages :  [1. 0.] [-1.25007684 -0.        ]
# action and advantages :  [1. 0.] [-1.4419863 -0.       ]
# action and advantages :  [1. 0.] [-1.63389575 -0.        ]
# X_batch size :  (72, 80, 80, 4)
# Y_batch size :  (72, 2)
# using batch_size =  72
# creating: createPGCriterion
# creating: createRMSprop
# creating: createMaxIteration
# creating: createDistriOptimizer
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-16-c79fb9d6b52a> in <module>()
#      26         rollouts = history.get_range(train_start, train_end)
#      27         print("training begin")
# ---> 28         learn(agent, rollouts)
#      29         end_of_train = timeit.default_timer()
#      30         exe_time_game_play = end_of_play - start_of_play
#
# <ipython-input-15-e74dba537797> in learn(agent, rollouts)
#      30         #optimizer.set_traindata(training_rdd=rdd_sample, batch_size=batch_size)
#      31         #optimizer.set_criterion(RFPGCriterion())
# ---> 32     agent.model = optimizer.optimize()
#
# /tmp/spark-25433582-dbf4-489a-a6f4-7e1b018755d8/userFiles-83310d67-5689-4efd-9c78-80a86124d48c/analytics-zoo-0.1.0-SNAPSHOT-python-api.zip/bigdl/optim/optimizer.py in optimize(self)
#     630         Do an optimization.
#     631         """
# --> 632         jmodel = callJavaFunc(self.value.optimize)
#     633         from bigdl.nn.layer import Layer
#     634         return Layer.of(jmodel)
#
# /tmp/spark-25433582-dbf4-489a-a6f4-7e1b018755d8/userFiles-83310d67-5689-4efd-9c78-80a86124d48c/analytics-zoo-0.1.0-SNAPSHOT-python-api.zip/bigdl/util/common.py in callJavaFunc(func, *args)
#     628     gateway = _get_gateway()
#     629     args = [_py2java(gateway, a) for a in args]
# --> 630     result = func(*args)
#     631     return _java2py(gateway, result)
#     632
#
# /usr/local/lib/spark/spark-1.6.0-bin-hadoop2.6/python/lib/py4j-0.9-src.zip/py4j/java_gateway.py in __call__(self, *args)
#     811         answer = self.gateway_client.send_command(command)
#     812         return_value = get_return_value(
# --> 813             answer, self.gateway_client, self.target_id, self.name)
#     814
#     815         for temp_arg in temp_args:
#
# /usr/local/lib/spark/spark-1.6.0-bin-hadoop2.6/python/pyspark/sql/utils.pyc in deco(*a, **kw)
#      43     def deco(*a, **kw):
#      44         try:
# ---> 45             return f(*a, **kw)
#      46         except py4j.protocol.Py4JJavaError as e:
#      47             s = e.java_exception.toString()
#
# /usr/local/lib/spark/spark-1.6.0-bin-hadoop2.6/python/lib/py4j-0.9-src.zip/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     306                 raise Py4JJavaError(
#     307                     "An error occurred while calling {0}{1}{2}.\n".
# --> 308                     format(target_id, ".", name), value)
#     309             else:
#     310                 raise Py4JError(
#
# Py4JJavaError: An error occurred while calling o109255.optimize.
# : org.apache.spark.SparkException: Job aborted due to stage failure: Task 0 in stage 5526.0 failed 1 times, most recent failure: Lost task 0.0 in stage 5526.0 (TID 36909, localhost): java.util.concurrent.ExecutionException: java.lang.OutOfMemoryError: Java heap space
# 	at java.util.concurrent.FutureTask.report(FutureTask.java:122)
# 	at java.util.concurrent.FutureTask.get(FutureTask.java:192)
# 	at com.intel.analytics.bigdl.optim.DistriOptimizer$$anonfun$5$$anonfun$8.apply(DistriOptimizer.scala:262)
# 	at com.intel.analytics.bigdl.optim.DistriOptimizer$$anonfun$5$$anonfun$8.apply(DistriOptimizer.scala:262)
# 	at scala.collection.TraversableLike$$anonfun$map$1.apply(TraversableLike.scala:244)
# 	at scala.collection.TraversableLike$$anonfun$map$1.apply(TraversableLike.scala:244)
# 	at scala.collection.mutable.ResizableArray$class.foreach(ResizableArray.scala:59)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:47)
# 	at scala.collection.TraversableLike$class.map(TraversableLike.scala:244)
# 	at scala.collection.AbstractTraversable.map(Traversable.scala:105)
# 	at com.intel.analytics.bigdl.optim.DistriOptimizer$$anonfun$5.apply(DistriOptimizer.scala:262)
# 	at com.intel.analytics.bigdl.optim.DistriOptimizer$$anonfun$5.apply(DistriOptimizer.scala:202)
# 	at org.apache.spark.rdd.ZippedPartitionsRDD2.compute(ZippedPartitionsRDD.scala:88)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:306)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:270)
# 	at org.apache.spark.scheduler.ResultTask.runTask(ResultTask.scala:66)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:89)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:213)
# 	at java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1142)
# 	at java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:617)
# 	at java.lang.Thread.run(Thread.java:745)
# Caused by: java.lang.OutOfMemoryError: Java heap space
# 	at scala.reflect.ManifestFactory$$anon$11.newArray(Manifest.scala:130)
# 	at scala.reflect.ManifestFactory$$anon$11.newArray(Manifest.scala:128)
# 	at com.intel.analytics.bigdl.tensor.DenseTensor$.rawResize(DenseTensor.scala:2346)
# 	at com.intel.analytics.bigdl.tensor.DenseTensor$.resize(DenseTensor.scala:2410)
# 	at com.intel.analytics.bigdl.tensor.DenseTensor.resize(DenseTensor.scala:122)
# 	at com.intel.analytics.bigdl.nn.SpatialConvolution.accGradParameters(SpatialConvolution.scala:466)
# 	at com.intel.analytics.bigdl.nn.SpatialConvolution.accGradParameters(SpatialConvolution.scala:54)
# 	at com.intel.analytics.bigdl.nn.keras.KerasLayer.accGradParameters(KerasLayer.scala:197)
# 	at com.intel.analytics.bigdl.nn.Sequential.accGradParameters(Sequential.scala:74)
# 	at com.intel.analytics.bigdl.nn.keras.KerasLayer.accGradParameters(KerasLayer.scala:197)
# 	at com.intel.analytics.bigdl.nn.abstractnn.AbstractModule.backward(AbstractModule.scala:269)
# 	at com.intel.analytics.bigdl.optim.DistriOptimizer$$anonfun$5$$anonfun$6$$anonfun$apply$2.apply$mcI$sp(DistriOptimizer.scala:253)
# 	at com.intel.analytics.bigdl.optim.DistriOptimizer$$anonfun$5$$anonfun$6$$anonfun$apply$2.apply(DistriOptimizer.scala:243)
# 	at com.intel.analytics.bigdl.optim.DistriOptimizer$$anonfun$5$$anonfun$6$$anonfun$apply$2.apply(DistriOptimizer.scala:243)
# 	at com.intel.analytics.bigdl.utils.ThreadPool$$anonfun$1$$anon$4.call(ThreadPool.scala:112)
# 	at java.util.concurrent.FutureTask.run(FutureTask.java:266)
# 	... 3 more
#
# Driver stacktrace:
# 	at org.apache.spark.scheduler.DAGScheduler.org$apache$spark$scheduler$DAGScheduler$$failJobAndIndependentStages(DAGScheduler.scala:1431)
# 	at org.apache.spark.scheduler.DAGScheduler$$anonfun$abortStage$1.apply(DAGScheduler.scala:1419)
# 	at org.apache.spark.scheduler.DAGScheduler$$anonfun$abortStage$1.apply(DAGScheduler.scala:1418)
# 	at scala.collection.mutable.ResizableArray$class.foreach(ResizableArray.scala:59)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:47)
# 	at org.apache.spark.scheduler.DAGScheduler.abortStage(DAGScheduler.scala:1418)
# 	at org.apache.spark.scheduler.DAGScheduler$$anonfun$handleTaskSetFailed$1.apply(DAGScheduler.scala:799)
# 	at org.apache.spark.scheduler.DAGScheduler$$anonfun$handleTaskSetFailed$1.apply(DAGScheduler.scala:799)
# 	at scala.Option.foreach(Option.scala:236)
# 	at org.apache.spark.scheduler.DAGScheduler.handleTaskSetFailed(DAGScheduler.scala:799)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.doOnReceive(DAGScheduler.scala:1640)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.onReceive(DAGScheduler.scala:1599)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.onReceive(DAGScheduler.scala:1588)
# 	at org.apache.spark.util.EventLoop$$anon$1.run(EventLoop.scala:48)
# 	at org.apache.spark.scheduler.DAGScheduler.runJob(DAGScheduler.scala:620)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:1832)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:1952)
# 	at org.apache.spark.rdd.RDD$$anonfun$reduce$1.apply(RDD.scala:1025)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:150)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:111)
# 	at org.apache.spark.rdd.RDD.withScope(RDD.scala:316)
# 	at org.apache.spark.rdd.RDD.reduce(RDD.scala:1007)
# 	at com.intel.analytics.bigdl.optim.DistriOptimizer$.optimize(DistriOptimizer.scala:312)
# 	at com.intel.analytics.bigdl.optim.DistriOptimizer.optimize(DistriOptimizer.scala:914)
# 	at sun.reflect.GeneratedMethodAccessor88.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:497)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:231)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:381)
# 	at py4j.Gateway.invoke(Gateway.java:259)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:133)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:209)
# 	at java.lang.Thread.run(Thread.java:745)
# Caused by: java.util.concurrent.ExecutionException: java.lang.OutOfMemoryError: Java heap space
# 	at java.util.concurrent.FutureTask.report(FutureTask.java:122)
# 	at java.util.concurrent.FutureTask.get(FutureTask.java:192)
# 	at com.intel.analytics.bigdl.optim.DistriOptimizer$$anonfun$5$$anonfun$8.apply(DistriOptimizer.scala:262)
# 	at com.intel.analytics.bigdl.optim.DistriOptimizer$$anonfun$5$$anonfun$8.apply(DistriOptimizer.scala:262)
# 	at scala.collection.TraversableLike$$anonfun$map$1.apply(TraversableLike.scala:244)
# 	at scala.collection.TraversableLike$$anonfun$map$1.apply(TraversableLike.scala:244)
# 	at scala.collection.mutable.ResizableArray$class.foreach(ResizableArray.scala:59)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:47)
# 	at scala.collection.TraversableLike$class.map(TraversableLike.scala:244)
# 	at scala.collection.AbstractTraversable.map(Traversable.scala:105)
# 	at com.intel.analytics.bigdl.optim.DistriOptimizer$$anonfun$5.apply(DistriOptimizer.scala:262)
# 	at com.intel.analytics.bigdl.optim.DistriOptimizer$$anonfun$5.apply(DistriOptimizer.scala:202)
# 	at org.apache.spark.rdd.ZippedPartitionsRDD2.compute(ZippedPartitionsRDD.scala:88)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:306)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:270)
# 	at org.apache.spark.scheduler.ResultTask.runTask(ResultTask.scala:66)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:89)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:213)
# 	at java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1142)
# 	at java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:617)
# 	... 1 more
# Caused by: java.lang.OutOfMemoryError: Java heap space
# 	at scala.reflect.ManifestFactory$$anon$11.newArray(Manifest.scala:130)
# 	at scala.reflect.ManifestFactory$$anon$11.newArray(Manifest.scala:128)
# 	at com.intel.analytics.bigdl.tensor.DenseTensor$.rawResize(DenseTensor.scala:2346)
# 	at com.intel.analytics.bigdl.tensor.DenseTensor$.resize(DenseTensor.scala:2410)
# 	at com.intel.analytics.bigdl.tensor.DenseTensor.resize(DenseTensor.scala:122)
# 	at com.intel.analytics.bigdl.nn.SpatialConvolution.accGradParameters(SpatialConvolution.scala:466)
# 	at com.intel.analytics.bigdl.nn.SpatialConvolution.accGradParameters(SpatialConvolution.scala:54)
# 	at com.intel.analytics.bigdl.nn.keras.KerasLayer.accGradParameters(KerasLayer.scala:197)
# 	at com.intel.analytics.bigdl.nn.Sequential.accGradParameters(Sequential.scala:74)
# 	at com.intel.analytics.bigdl.nn.keras.KerasLayer.accGradParameters(KerasLayer.scala:197)
# 	at com.intel.analytics.bigdl.nn.abstractnn.AbstractModule.backward(AbstractModule.scala:269)
# 	at com.intel.analytics.bigdl.optim.DistriOptimizer$$anonfun$5$$anonfun$6$$anonfun$apply$2.apply$mcI$sp(DistriOptimizer.scala:253)
# 	at com.intel.analytics.bigdl.optim.DistriOptimizer$$anonfun$5$$anonfun$6$$anonfun$apply$2.apply(DistriOptimizer.scala:243)
# 	at com.intel.analytics.bigdl.optim.DistriOptimizer$$anonfun$5$$anonfun$6$$anonfun$apply$2.apply(DistriOptimizer.scala:243)
# 	at com.intel.analytics.bigdl.utils.ThreadPool$$anonfun$1$$anon$4.call(ThreadPool.scala:112)
# 	at java.util.concurrent.FutureTask.run(FutureTask.java:266)
# 	... 3 more

# %%
# %%matplotlib inline
# import seaborn
# plt.style.use('bmh')
# arr = np.asarray(record)
# print arr.shape
# fig, ax1 = plt.subplots()
# ind=np.arange(0,arr.shape[0],1)
# #t = np.arange(0.01, 10.0, 0.01)
# #s1 = np.exp(t)
# ax1.plot(ind,arr[:,0], 'b-')
# ax1.set_xlabel('no. of updates')
# ax1.set_xticks(ind[::5])
# # Make the y-axis label, ticks and tick labels match the line color.
# ax1.set_ylabel('score mean', color='b')
# ax1.tick_params('y', colors='b')
#
# ax2 = ax1.twinx()
# ax2.plot(ind,arr[:,1], 'g--')
# ax2.set_ylabel('score variance', color='g')
# ax2.tick_params('y', colors='g')
# plt.grid(True)
# #fig.tight_layout()
# plt.title('BigDL REINFORCE PG (Flappy Bird)');
